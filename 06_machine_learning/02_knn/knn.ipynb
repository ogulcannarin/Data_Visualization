# %%
import pandas as pd

df = pd.read_csv("Iris.csv")

print(df.head())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0    150            5.9           3.0            5.1           1.8
# 1     49            5.3           3.7            1.5           0.2
# 2    123            7.7           2.8            6.7           2.0
# 3    130            7.2           3.0            5.8           1.6
# 4     14            4.3           3.0            1.1           0.1
# ..   ...            ...           ...            ...           ...
# 145   53            6.9           3.1            4.9           1.5
# 146   82            5.5           2.4            3.7           1.0
# 147   85            5.4           3.0            4.5           1.5
# 148   72            6.1           2.8            4.0           1.3
# 149   40            5.1           3.4            1.5           0.2
#
#              Species
# 0     Iris-virginica
# 1        Iris-setosa
# 2     Iris-virginica
# 3     Iris-virginica
# 4        Iris-setosa
# ..               ...
# 145  Iris-versicolor
# 146  Iris-versicolor
# 147  Iris-versicolor
# 148  Iris-versicolor
# 149      Iris-setosa
#
# [150 rows x 6 columns]

# %%
le = LabelEncoder()
df['Species'] = le.fit_transform(df['Species'])

# %%
X = df.drop(['Species'], axis=1)
y = df['Species']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(x_test)

# %%
y_pred
# Out:
# array([2, 1, 0, 1, 1, 0, 1, 2, 1, 2, 2, 1, 0, 1, 1, 1, 2, 1, 1, 0, 0, 1,
#        2, 0, 2, 1, 1, 0, 2, 2, 2, 2, 2, 0, 2, 1, 0, 0, 0, 2, 0, 2, 1, 0,
#        0])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[14  0  0]
#  [ 0 16  0]
#  [ 0  0 15]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel("Tahmin")
plt.ylabel("Gerçek")
plt.show()
